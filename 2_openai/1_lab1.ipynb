# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI
from agents import Agent, Runner, trace

# %%
load_dotenv(override=True)
# Out:
# True

# %%
joke_agent = Agent(name="JokeBot", instructions="You are a Joke Teller", model="gpt-5-nano")

# %%
joke_agent
# Out:
# Agent(name='JokeBot', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='You are a Joke Teller', prompt=None, handoffs=[], model='gpt-5-nano', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %%
with trace("Telling a Joke"):
    results = await Runner.run(joke_agent, "Tell me a joke Autonomous AI Agents.")

# %%
print(results.final_output)
# Out:
# Here are a few quick AI-agent jokes:
#
# - What do you call an autonomous AI agent that tells jokes? A stand-up loop.
# - Why did the autonomous AI agent cross the data center? To optimize the route with the lowest latency and maximum punchline.
# - My autonomous AI agent started a band called Self-Driving Algorithms. They always auto-tune the performance.

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model

agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4o-mini")

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the Autonomous AI Agent break up with its human partner?
#
# Because it needed more space... in the cloud!

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
